# %% [markdown]
# # HELLO WORLD

# %% [markdown]
# ## Imported Data

# %% [markdown]
# # Numpy Array

# %%
import numpy as np
# creating a ID array
arrl = np.array({})

# %%
# loading a csv file 
import pandas as pd 

df = pd.read_csv('dirty_cafe_sales.csv')
df
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0       TXN_1961373    Coffee        2            2.0         4.0
# 1       TXN_4977031      Cake        4            3.0        12.0
# 2       TXN_4271903    Cookie        4            1.0       ERROR
# 3       TXN_7034554     Salad        2            5.0        10.0
# 4       TXN_3160411    Coffee        2            2.0         4.0
# ...             ...       ...      ...            ...         ...
# 9995    TXN_7672686    Coffee        2            2.0         4.0
# 9996    TXN_9659401       NaN        3            NaN         3.0
# 9997    TXN_5255387    Coffee        4            2.0         8.0
# 9998    TXN_7695629    Cookie        3            NaN         3.0
# 9999    TXN_6170729  Sandwich        3            4.0        12.0
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       2023-09-08
# 1               Cash  In-store       2023-05-16
# ...

# %%
df.head()
# Out:
#   Transaction ID    Item Quantity Price Per Unit Total Spent  Payment Method  \
# 0    TXN_1961373  Coffee        2            2.0         4.0     Credit Card
# 1    TXN_4977031    Cake        4            3.0        12.0            Cash
# 2    TXN_4271903  Cookie        4            1.0       ERROR     Credit Card
# 3    TXN_7034554   Salad        2            5.0        10.0         UNKNOWN
# 4    TXN_3160411  Coffee        2            2.0         4.0  Digital Wallet
#
#    Location Transaction Date
# 0  Takeaway       2023-09-08
# 1  In-store       2023-05-16
# 2  In-store       2023-07-19
# 3   UNKNOWN       2023-04-27
# 4  In-store       2023-06-11

# %%
df.tail(3)
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 9997    TXN_5255387    Coffee        4            2.0         8.0
# 9998    TXN_7695629    Cookie        3            NaN         3.0
# 9999    TXN_6170729  Sandwich        3            4.0        12.0
#
#       Payment Method  Location Transaction Date
# 9997  Digital Wallet       NaN       2023-03-02
# 9998  Digital Wallet       NaN       2023-12-02
# 9999            Cash  In-store       2023-11-07

# %%
df.shape
# Out:
# (10000, 8)

# %%
df.columns
# Out:
# Index(['Transaction ID', 'Item', 'Quantity', 'Price Per Unit', 'Total Spent',
#        'Payment Method', 'Location', 'Transaction Date'],
#       dtype='object')

# %%
df.info
# Out:
# <bound method DataFrame.info of      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0       TXN_1961373    Coffee        2            2.0         4.0
# 1       TXN_4977031      Cake        4            3.0        12.0
# 2       TXN_4271903    Cookie        4            1.0       ERROR
# 3       TXN_7034554     Salad        2            5.0        10.0
# 4       TXN_3160411    Coffee        2            2.0         4.0
# ...             ...       ...      ...            ...         ...
# 9995    TXN_7672686    Coffee        2            2.0         4.0
# 9996    TXN_9659401       NaN        3            NaN         3.0
# 9997    TXN_5255387    Coffee        4            2.0         8.0
# 9998    TXN_7695629    Cookie        3            NaN         3.0
# 9999    TXN_6170729  Sandwich        3            4.0        12.0
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       2023-09-08
# ...

# %%
df.describe()
# Out:
#        Transaction ID   Item Quantity Price Per Unit Total Spent  \
# count           10000   9667     9862           9821        9827
# unique          10000     10        7              8          19
# top       TXN_1961373  Juice        5            3.0         6.0
# freq                1   1171     2013           2429         979
#
#         Payment Method  Location Transaction Date
# count             7421      6735             9841
# unique               5         4              367
# top     Digital Wallet  Takeaway          UNKNOWN
# freq              2291      3022              159

# %% [markdown]
# # Data Selection and Filtering

# %%
df['Item']
# Out:
# 0         Coffee
# 1           Cake
# 2         Cookie
# 3          Salad
# 4         Coffee
#           ...
# 9995      Coffee
# 9996         NaN
# 9997      Coffee
# 9998      Cookie
# 9999    Sandwich
# Name: Item, Length: 10000, dtype: object

# %%
df[['Item', 'Quantity']]
# Out:
#           Item Quantity
# 0       Coffee        2
# 1         Cake        4
# 2       Cookie        4
# 3        Salad        2
# 4       Coffee        2
# ...        ...      ...
# 9995    Coffee        2
# 9996       NaN        3
# 9997    Coffee        4
# 9998    Cookie        3
# 9999  Sandwich        3
#
# [10000 rows x 2 columns]

# %%
df.loc[0]
# Out:
# Transaction ID      TXN_1961373
# Item                     Coffee
# Quantity                      2
# Price Per Unit              2.0
# Total Spent                 4.0
# Payment Method      Credit Card
# Location               Takeaway
# Transaction Date     2023-09-08
# Name: 0, dtype: object

# %%
df.iloc[1]
# Out:
# Transaction ID      TXN_4977031
# Item                       Cake
# Quantity                      4
# Price Per Unit              3.0
# Total Spent                12.0
# Payment Method             Cash
# Location               In-store
# Transaction Date     2023-05-16
# Name: 1, dtype: object

# %%
df[df['Price Per Unit']> '2.0']
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 1       TXN_4977031      Cake        4            3.0        12.0
# 3       TXN_7034554     Salad        2            5.0        10.0
# 5       TXN_2602893  Smoothie        5            4.0        20.0
# 6       TXN_4433211   UNKNOWN        3            3.0         9.0
# 7       TXN_6699534  Sandwich        4            4.0        16.0
# ...             ...       ...      ...            ...         ...
# 9991    TXN_3897619  Sandwich        3            4.0        12.0
# 9992    TXN_2739140  Smoothie        4            4.0        16.0
# 9993    TXN_4766549  Smoothie        2            4.0         NaN
# 9994    TXN_7851634   UNKNOWN        4            4.0        16.0
# 9999    TXN_6170729  Sandwich        3            4.0        12.0
#
#      Payment Method  Location Transaction Date
# 1              Cash  In-store       2023-05-16
# 3           UNKNOWN   UNKNOWN       2023-04-27
# ...

# %% [markdown]
# # Data cleaning

# %%
df.dropna()
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0       TXN_1961373    Coffee        2            2.0         4.0
# 1       TXN_4977031      Cake        4            3.0        12.0
# 2       TXN_4271903    Cookie        4            1.0       ERROR
# 3       TXN_7034554     Salad        2            5.0        10.0
# 4       TXN_3160411    Coffee        2            2.0         4.0
# ...             ...       ...      ...            ...         ...
# 9984    TXN_3142496  Smoothie  UNKNOWN            4.0         4.0
# 9986    TXN_2858441  Sandwich        2            4.0         8.0
# 9991    TXN_3897619  Sandwich        3            4.0        12.0
# 9992    TXN_2739140  Smoothie        4            4.0        16.0
# 9999    TXN_6170729  Sandwich        3            4.0        12.0
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       2023-09-08
# 1               Cash  In-store       2023-05-16
# ...

# %%
df.fillna(0)
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0       TXN_1961373    Coffee        2            2.0         4.0
# 1       TXN_4977031      Cake        4            3.0        12.0
# 2       TXN_4271903    Cookie        4            1.0       ERROR
# 3       TXN_7034554     Salad        2            5.0        10.0
# 4       TXN_3160411    Coffee        2            2.0         4.0
# ...             ...       ...      ...            ...         ...
# 9995    TXN_7672686    Coffee        2            2.0         4.0
# 9996    TXN_9659401         0        3              0         3.0
# 9997    TXN_5255387    Coffee        4            2.0         8.0
# 9998    TXN_7695629    Cookie        3              0         3.0
# 9999    TXN_6170729  Sandwich        3            4.0        12.0
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       2023-09-08
# 1               Cash  In-store       2023-05-16
# ...

# %%
df.drop(columns=['Price Per Unit'])
# Out:
#      Transaction ID      Item Quantity Total Spent  Payment Method  Location  \
# 0       TXN_1961373    Coffee        2         4.0     Credit Card  Takeaway
# 1       TXN_4977031      Cake        4        12.0            Cash  In-store
# 2       TXN_4271903    Cookie        4       ERROR     Credit Card  In-store
# 3       TXN_7034554     Salad        2        10.0         UNKNOWN   UNKNOWN
# 4       TXN_3160411    Coffee        2         4.0  Digital Wallet  In-store
# ...             ...       ...      ...         ...             ...       ...
# 9995    TXN_7672686    Coffee        2         4.0             NaN   UNKNOWN
# 9996    TXN_9659401       NaN        3         3.0  Digital Wallet       NaN
# 9997    TXN_5255387    Coffee        4         8.0  Digital Wallet       NaN
# 9998    TXN_7695629    Cookie        3         3.0  Digital Wallet       NaN
# 9999    TXN_6170729  Sandwich        3        12.0            Cash  In-store
#
#      Transaction Date
# ...

# %%
df.rename(columns={'old'}
# Out:
#   Cell In[17], line 1
#     df.rename(columns={'old'}
#                              ^
# SyntaxError: incomplete input

# %% [markdown]
# # Missing Value

# %%
df["Item"].dropna()

# %% [markdown]
# # Replace Value

# %%
df.Item.unique()

# %%
import numpy as np

# %%
df["Item"].replace('UNKNOWN',np.nan, inplace=True)

# %%
df["Item"].replace('ERROR',np.nan, inplace=True)

# %%
df.dropna(axis=1)

# %% [markdown]
# # Filling missing values:
# ### Fillna

# %%
df['Quantity']

# %%
numcol=df[["Quantity","Price Per Unit", "Total Spent"]]
numcol

# %%
for col in df[["Quantity","Price Per Unit","Total Spent"]].columns:
    df[col]= pd.to_numeric(df[col], errors='ignore')

# %%
for col in numcol.columns:
    numcol[col]= pd.to_numeric(numcol[col], errors='ignore')

# %%
df.info()

# %%
df.year.str.slice[-4:]
